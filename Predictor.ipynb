# %% [markdown]
# <a href="https://colab.research.google.com/github/akhiluthappa1/crypto_predict/blob/main/Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Bitcoin Price prediction using Facebook Prophet

# %%
## Switch to GPU mode for faster Computation (Runtime> Change runtime> GPU)

# %% [markdown]
# ## Importing Necessary Libraries

# %%
#Necessary libraries = Pandas, fbprophet and plotly

#pandas= data Manipulation and analysis
#fbprophet = Forecasting
#plotly= data visualization

# %%
import pandas as pd
from fbprophet import Prophet
import plotly.express as px

# %%
 #Initializing Plotly
 import plotly.io as pio
 pio.renderers.default = 'colab'

# %% [markdown]
# ## Importing the Dataset & Exploring it

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-92746798-03b2-4ddc-b10f-a0a0fc4f2d0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92746798-03b2-4ddc-b10f-a0a0fc4f2d0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bitcoin_data.csv to bitcoin_data.csv
# ...

# %%
#read_csv function from pandas
df = pd.read_csv("bitcoin_data.csv")

# %%
df
# Out:
#            Date     Close
# 0      1/1/2016    435.66
# 1      1/2/2016    435.40
# 2      1/3/2016    431.91
# 3      1/4/2016    433.85
# 4      1/5/2016    433.34
# ...         ...       ...
# 1700  8/27/2020  11329.10
# 1701  8/28/2020  11535.00
# 1702  8/29/2020  11474.30
# 1703  8/30/2020  11716.00
# 1704  8/31/2020  11655.00
#
# [1705 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1705 non-null   object
#  1   Close   1705 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 26.8+ KB

# %%
df.info
# Out:
# <bound method DataFrame.info of            Date     Close
# 0      1/1/2016    435.66
# 1      1/2/2016    435.40
# 2      1/3/2016    431.91
# 3      1/4/2016    433.85
# 4      1/5/2016    433.34
# ...         ...       ...
# 1700  8/27/2020  11329.10
# 1701  8/28/2020  11535.00
# 1702  8/29/2020  11474.30
# 1703  8/30/2020  11716.00
# 1704  8/31/2020  11655.00
#
# [1705 rows x 2 columns]>

# %%
df.describe()
# Out:
#               Close
# count   1705.000000
# mean    5455.314499
# std     3962.263892
# min      357.530000
# 25%     1062.150000
# 50%     6005.050000
# 75%     8624.280000
# max    19650.010000

# %% [markdown]
# # Data Visualization

# %%
# Area graph (Date Vs Price)
px.area(data_frame=df, x='Date', y = 'Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a4cfacfe-0416-4225-8109-43b6c0273157" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4cfacfe-0416-4225-8109-43b6c0273157")) {
#                     Plotly.newPlot(
#                         'a4cfacfe-0416-4225-8109-43b6c0273157',
# ...

# %%
# Violin plot
px.violin(df, y="Close")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="98c7f108-d840-4d82-aebb-a2d68008722b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("98c7f108-d840-4d82-aebb-a2d68008722b")) {
#                     Plotly.newPlot(
#                         '98c7f108-d840-4d82-aebb-a2d68008722b',
# ...

# %% [markdown]
# # Creating Facebook Prophet Model

# %% [markdown]
# ![Facebook Prophet (2).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Facebook Prophet.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Data Preperation

# %%
df
# Out:
#            Date     Close
# 0      1/1/2016    435.66
# 1      1/2/2016    435.40
# 2      1/3/2016    431.91
# 3      1/4/2016    433.85
# 4      1/5/2016    433.34
# ...         ...       ...
# 1700  8/27/2020  11329.10
# 1701  8/28/2020  11535.00
# 1702  8/29/2020  11474.30
# 1703  8/30/2020  11716.00
# 1704  8/31/2020  11655.00
#
# [1705 rows x 2 columns]

# %%
  prophet_df = df.rename(columns = {"Date": "ds", "Close": "y"})

# %%
prophet_df
# Out:
#              ds         y
# 0      1/1/2016    435.66
# 1      1/2/2016    435.40
# 2      1/3/2016    431.91
# 3      1/4/2016    433.85
# 4      1/5/2016    433.34
# ...         ...       ...
# 1700  8/27/2020  11329.10
# 1701  8/28/2020  11535.00
# 1702  8/29/2020  11474.30
# 1703  8/30/2020  11716.00
# 1704  8/31/2020  11655.00
#
# [1705 rows x 2 columns]

# %% [markdown]
# ## Modelling

# %%
m = Prophet()
m.fit(prophet_df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ##Forecasting

# %%
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)

# %%
forecast
# Out:
#              ds        trend  ...  multiplicative_terms_upper         yhat
# 0    2016-01-01  1024.030928  ...                         0.0  1391.439699
# 1    2016-01-02  1020.292562  ...                         0.0  1367.168143
# 2    2016-01-03  1016.554196  ...                         0.0  1302.303934
# 3    2016-01-04  1012.815830  ...                         0.0  1291.480175
# 4    2016-01-05  1009.077464  ...                         0.0  1232.302026
# ...         ...          ...  ...                         ...          ...
# 1730 2020-09-26  9075.188181  ...                         0.0  8985.819287
# 1731 2020-09-27  9075.741437  ...                         0.0  8924.510535
# 1732 2020-09-28  9076.294693  ...                         0.0  8915.095136
# 1733 2020-09-29  9076.847948  ...                         0.0  8855.426969
# 1734 2020-09-30  9077.401204  ...                         0.0  8825.431639
#
# [1735 rows x 19 columns]

# %%
figure = m.plot(forecast, xlabel="Date", ylabel="Price")

# %%
figure2 = m.plot_components(forecast)

# %% [markdown]
# ##Downloading the Forecast data

# %%
forecast.to_csv("forecast.csv")
from google.colab import files
files.download("forecast.csv")
